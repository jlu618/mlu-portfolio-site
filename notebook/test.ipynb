# %%
import time
import os

# %%
import json
from pathlib import Path
from datetime import datetime

import streamlit as st
from PIL import Image, ImageOps

# --- Page config (Streamlit reads this page standalone, but it's ok to set here) ---
st.set_page_config(page_title="Photos", page_icon="📸", layout="wide")

# --- Paths ---
ROOT = Path.cwd()
# Out:
# 2026-02-17 16:05:52.558 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
ROOT
# Out:
# WindowsPath('d:/Python/mlu-portfolio-site/notebook')
